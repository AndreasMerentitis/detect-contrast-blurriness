# %% [markdown]
# This notebook runs an example batch classification of images and stores the results in a json file. The intention is to showcase the functionality in jupyter-repo2docker.

# %%
! python batch.py -i parts_vehicles/ -s results.json -f
# Out:
# INFO:root:processing parts_vehicles/55386_0.png
# INFO:root:input_path: parts_vehicles/55386_0.png, clearness_score: 8.090896459538072, blurry: False, contrast_score: 0.4646756862745098, low_contrast: False
# INFO:root:processing parts_vehicles/22595_0.png
# INFO:root:input_path: parts_vehicles/22595_0.png, clearness_score: 9.398855830429769, blurry: False, contrast_score: 0.380392156862745, low_contrast: False
# INFO:root:processing parts_vehicles/27055_0.png
# INFO:root:input_path: parts_vehicles/27055_0.png, clearness_score: 4.958490437839817, blurry: True, contrast_score: 0.4289617647058823, low_contrast: False
# INFO:root:processing parts_vehicles/92676_0.png
# INFO:root:input_path: parts_vehicles/92676_0.png, clearness_score: 13.800132987037399, blurry: False, contrast_score: 0.36161058823529413, low_contrast: False
# INFO:root:processing parts_vehicles/70364_0.png
# ...
